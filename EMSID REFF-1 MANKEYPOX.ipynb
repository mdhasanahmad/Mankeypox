# %%
# # This Python 3 environment comes with many helpful analytics libraries installed
# # It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# # For example, here's several helpful packages to load

# import numpy as np # linear algebra
# import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# # Input data files are available in the read-only "../input/" directory
# # For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

# import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))

# # You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# # You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# ============================================================
# FULL KAGGLE NOTEBOOK (Monkeypox multi-class)
# Ensemble CNN backbones + lightweight ViT block
# + Confusion Matrix + ROC
# + Bootstrap 95% Confidence Intervals for performance metrics
# ============================================================

import os
import random
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

from tensorflow.keras import layers, models, Input
from tensorflow.keras.applications import ResNet50, EfficientNetB0, DenseNet121, Xception
from tensorflow.keras.applications.resnet50 import preprocess_input as resnet_pre
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.utils import to_categorical

from sklearn.model_selection import train_test_split
from sklearn.metrics import (
    confusion_matrix, ConfusionMatrixDisplay,
    roc_curve, auc,
    classification_report, cohen_kappa_score,
    precision_recall_fscore_support, accuracy_score,
    roc_auc_score
)

# -----------------------------
# CONFIG
# -----------------------------
SEED = 42
IMAGE_SIZE = (224, 224)
NUM_CLASSES = 8
BATCH_SIZE = 32
EPOCHS = 100
SAMPLES_PER_CLASS = 1000
DATA_DIR = "/kaggle/input/esmid-dataset-ref-1/archive"  # update if needed

# -----------------------------
# REPRODUCIBILITY
# -----------------------------
os.environ["PYTHONHASHSEED"] = str(SEED)
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

# -----------------------------
# LOAD & BALANCE DATA IN MEMORY
# -----------------------------
print("📦 Loading and sampling images per class...")

class_names = sorted([d for d in os.listdir(DATA_DIR) if os.path.isdir(os.path.join(DATA_DIR, d))])
print("Classes:", class_names)

all_images, all_labels_idx = [], []

for idx, class_name in enumerate(class_names):
    class_dir = os.path.join(DATA_DIR, class_name)
    image_files = [f for f in os.listdir(class_dir) if f.lower().endswith((".jpg", ".jpeg", ".png"))]

    if len(image_files) == 0:
        print(f"⚠️ No images found in: {class_dir}")
        continue

    selected = random.sample(image_files, min(SAMPLES_PER_CLASS, len(image_files)))

    for file in selected:
        img = load_img(os.path.join(class_dir, file), target_size=IMAGE_SIZE)
        img_array = img_to_array(img)
        img_array = resnet_pre(img_array)  # using ResNet preprocess for all (OK, but you can also match each backbone)
        all_images.append(img_array)
        all_labels_idx.append(idx)

all_images = np.array(all_images, dtype=np.float32)
all_labels_idx = np.array(all_labels_idx, dtype=np.int32)
all_labels_oh = to_categorical(all_labels_idx, num_classes=NUM_CLASSES)

print("Total images:", len(all_images))

# -----------------------------
# SPLIT (stratify must use class indices, NOT one-hot)
# -----------------------------
X_train, X_val, y_train, y_val, y_train_idx, y_val_idx = train_test_split(
    all_images, all_labels_oh, all_labels_idx,
    test_size=0.2,
    stratify=all_labels_idx,
    random_state=SEED
)

print("Train:", X_train.shape, y_train.shape)
print("Val  :", X_val.shape, y_val.shape)

# -----------------------------
# ViT BLOCK (small)
# -----------------------------
def create_vit_block(input_shape, projection_dim=64, num_heads=4, transformer_layers=4, patch_size=16):
    inputs = Input(shape=input_shape)

    # patch embedding
    num_patches = (input_shape[0] // patch_size) * (input_shape[1] // patch_size)
    x = layers.Conv2D(filters=projection_dim, kernel_size=patch_size, strides=patch_size, padding="valid")(inputs)
    x = layers.Reshape((num_patches, projection_dim))(x)

    # position embedding
    positions = tf.range(start=0, limit=num_patches, delta=1)
    pos_embed = layers.Embedding(input_dim=num_patches, output_dim=projection_dim)(positions)
    x = x + pos_embed

    # transformer encoder
    for _ in range(transformer_layers):
        x1 = layers.LayerNormalization(epsilon=1e-6)(x)
        attn = layers.MultiHeadAttention(num_heads=num_heads, key_dim=projection_dim)(x1, x1)
        x2 = layers.Add()([x, attn])

        x3 = layers.LayerNormalization(epsilon=1e-6)(x2)
        ffn = tf.keras.Sequential([
            layers.Dense(4 * projection_dim, activation="gelu"),
            layers.Dropout(0.1),
            layers.Dense(projection_dim),
        ])(x3)
        x = layers.Add()([x2, ffn])

    x = layers.LayerNormalization(epsilon=1e-6)(x)
    x = layers.GlobalAveragePooling1D()(x)
    return models.Model(inputs, x, name="ViT_Block")

# -----------------------------
# FEATURE EXTRACTION BACKBONES
# -----------------------------
input_layer = Input(shape=(224, 224, 3))

resnet = ResNet50(include_top=False, weights="imagenet", input_shape=(224, 224, 3))
efficientnet = EfficientNetB0(include_top=False, weights="imagenet", input_shape=(224, 224, 3))
densenet = DenseNet121(include_top=False, weights="imagenet", input_shape=(224, 224, 3))
xception = Xception(include_top=False, weights="imagenet", input_shape=(224, 224, 3))

for base in [resnet, efficientnet, densenet, xception]:
    base.trainable = False

def extract_features(base_model, x):
    x = base_model(x, training=False)
    x = layers.GlobalAveragePooling2D()(x)
    return x

resnet_feat = extract_features(resnet, input_layer)
efficientnet_feat = extract_features(efficientnet, input_layer)
densenet_feat = extract_features(densenet, input_layer)
xception_feat = extract_features(xception, input_layer)

vit_feat = create_vit_block((224, 224, 3))(input_layer)

# -----------------------------
# FUSION + CLASSIFIER
# -----------------------------
combined = layers.Concatenate()([resnet_feat, efficientnet_feat, densenet_feat, xception_feat, vit_feat])

x = layers.Dense(512, activation="relu")(combined)
x = layers.Dropout(0.5)(x)
output = layers.Dense(NUM_CLASSES, activation="softmax")(x)

model = models.Model(inputs=input_layer, outputs=output)
model.compile(
    optimizer=tf.keras.optimizers.Adam(1e-4),
    loss="categorical_crossentropy",
    metrics=["accuracy"]
)

model.summary()

# -----------------------------
# TRAIN
# -----------------------------
callbacks = [
    tf.keras.callbacks.EarlyStopping(monitor="val_accuracy", patience=12, restore_best_weights=True),
    tf.keras.callbacks.ReduceLROnPlateau(monitor="val_loss", factor=0.5, patience=5, min_lr=1e-6)
]

history = model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    callbacks=callbacks,
    verbose=1
)

# -----------------------------
# PLOT ACCURACY & LOSS
# -----------------------------
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history.history["accuracy"], label="Train")
plt.plot(history.history["val_accuracy"], label="Validation")
plt.title("Accuracy")
plt.legend()
plt.grid(True)

plt.subplot(1, 2, 2)
plt.plot(history.history["loss"], label="Train")
plt.plot(history.history["val_loss"], label="Validation")
plt.title("Loss")
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# -----------------------------
# EVALUATION (VAL AS TEST)
# -----------------------------
test_loss, test_acc = model.evaluate(X_val, y_val, batch_size=32, verbose=0)
print(f"✅ Test Accuracy (Val): {test_acc*100:.2f}%")

y_pred = model.predict(X_val, batch_size=32, verbose=0)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true_classes = np.argmax(y_val, axis=1)

# -----------------------------
# CONFUSION MATRIX
# -----------------------------
cm = confusion_matrix(y_true_classes, y_pred_classes)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names)
disp.plot(xticks_rotation=45, cmap="Blues")
plt.title("Confusion Matrix")
plt.tight_layout()
plt.show()

# -----------------------------
# ROC CURVE (one-vs-rest per class)
# -----------------------------
plt.figure(figsize=(10, 7))
for i in range(NUM_CLASSES):
    fpr, tpr, _ = roc_curve(y_val[:, i], y_pred[:, i])
    auc_score = auc(fpr, tpr)
    plt.plot(fpr, tpr, label=f"{class_names[i]} (AUC={auc_score:.2f})")

plt.plot([0, 1], [0, 1], "k--")
plt.xlabel("FPR")
plt.ylabel("TPR")
plt.title("ROC Curve (OvR)")
plt.legend()
plt.grid(True)
plt.show()

# -----------------------------
# CLASSIFICATION REPORT + KAPPA + SENSITIVITY
# -----------------------------
report = classification_report(y_true_classes, y_pred_classes, target_names=class_names, digits=4)
print("📊 Classification Report:\n", report)

kappa = cohen_kappa_score(y_true_classes, y_pred_classes)
print(f"✅ Cohen's Kappa Score: {kappa:.4f}")

sensitivity_per_class = precision_recall_fscore_support(y_true_classes, y_pred_classes, average=None)[1]
for idx, cls in enumerate(class_names):
    print(f"🔹 Sensitivity (Recall) for {cls}: {sensitivity_per_class[idx]:.4f}")

precision_micro, recall_micro, f1_micro, _ = precision_recall_fscore_support(
    y_true_classes, y_pred_classes, average="micro"
)
precision_macro, recall_macro, f1_macro, _ = precision_recall_fscore_support(
    y_true_classes, y_pred_classes, average="macro"
)
precision_weighted, recall_weighted, f1_weighted, _ = precision_recall_fscore_support(
    y_true_classes, y_pred_classes, average="weighted"
)

print("\n📌 Averages:")
print(f"Micro Average    -> Precision: {precision_micro:.4f}, Recall: {recall_micro:.4f}, F1-score: {f1_micro:.4f}")
print(f"Macro Average    -> Precision: {precision_macro:.4f}, Recall: {recall_macro:.4f}, F1-score: {f1_macro:.4f}")
print(f"Weighted Average -> Precision: {precision_weighted:.4f}, Recall: {recall_weighted:.4f}, F1-score: {f1_weighted:.4f}")

# ============================================================
# BOOTSTRAP 95% CONFIDENCE INTERVALS
# ============================================================
def bootstrap_ci(y_true_cls, y_prob, n_boot=2000, ci=95, seed=42):
    """
    y_true_cls: (N,) int labels
    y_prob    : (N, C) predicted probabilities
    Returns dict of metric -> (mean, low, high)
    """
    rng = np.random.default_rng(seed)
    n = len(y_true_cls)

    acc_list = []
    prec_macro_list = []
    rec_macro_list = []
    f1_macro_list = []
    kappa_list = []
    auc_ovr_macro_list = []

    # Convert true labels to one-hot for AUC
    y_true_oh = to_categorical(y_true_cls, num_classes=y_prob.shape[1])

    for _ in range(n_boot):
        idx = rng.integers(0, n, size=n)  # sample with replacement
        yt = y_true_cls[idx]
        yp = y_prob[idx]
        yp_cls = np.argmax(yp, axis=1)

        acc_list.append(accuracy_score(yt, yp_cls))

        p, r, f1, _ = precision_recall_fscore_support(yt, yp_cls, average="macro", zero_division=0)
        prec_macro_list.append(p)
        rec_macro_list.append(r)
        f1_macro_list.append(f1)

        kappa_list.append(cohen_kappa_score(yt, yp_cls))

        # AUC OvR macro (needs at least one sample per class in this bootstrap draw)
        # Handle rare failure safely:
        try:
            yt_oh = to_categorical(yt, num_classes=yp.shape[1])
            auc_ovr_macro_list.append(
                roc_auc_score(yt_oh, yp, multi_class="ovr", average="macro")
            )
        except Exception:
            # skip this draw if AUC cannot be computed
            pass

    def ci_bounds(values):
        values = np.array(values, dtype=np.float64)
        mean = float(np.mean(values))
        alpha = (100 - ci) / 2
        low = float(np.percentile(values, alpha))
        high = float(np.percentile(values, 100 - alpha))
        return mean, low, high

    out = {
        "Accuracy": ci_bounds(acc_list),
        "Precision (macro)": ci_bounds(prec_macro_list),
        "Recall (macro)": ci_bounds(rec_macro_list),
        "F1 (macro)": ci_bounds(f1_macro_list),
        "Cohen's Kappa": ci_bounds(kappa_list),
    }
    if len(auc_ovr_macro_list) > 50:
        out["AUC (ovr-macro)"] = ci_bounds(auc_ovr_macro_list)
    else:
        out["AUC (ovr-macro)"] = ("NA", "NA", "NA")

    return out

ci_results = bootstrap_ci(y_true_classes, y_pred, n_boot=2000, ci=95, seed=SEED)

print("\n================ BOOTSTRAP 95% CI (Val set) ================")
for k, v in ci_results.items():
    if v[0] == "NA":
        print(f"{k}: NA (not enough valid bootstrap samples)")
    else:
        mean, low, high = v
        print(f"{k}: {mean:.4f} (95% CI: {low:.4f} – {high:.4f})")

# Also print the single-shot AUC (ovr-macro) on full val (not bootstrap)
try:
    auc_full = roc_auc_score(y_val, y_pred, multi_class="ovr", average="macro")
    print(f"\nAUC (ovr-macro) on full Val: {auc_full:.4f}")
except Exception as e:
    print("\nAUC (ovr-macro) on full Val: could not compute ->", e)
# Out:
# 2026-02-26 17:01:40.003669: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1772125300.229699      55 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1772125300.291646      55 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1772125300.772073      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1772125300.772127      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1772125300.772130      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1772125300.772132      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 📦 Loading and sampling images per class...
# Classes: ['Chickenpox', 'Eczema', 'Lupus', 'Measles', 'Molluscum', 'Monkeypox', 'Normal', 'Scabies']
# Total images: 8000
# Train: (6400, 224, 224, 3) (6400, 8)
# Val  : (1600, 224, 224, 3) (1600, 8)
# I0000 00:00:1772125392.679865      55 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15511 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29084464/29084464 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83683744/83683744 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# Model: "functional_4"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 224, 224,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ resnet50            │ (None, 7, 7,      │ 23,587,712 │ input_layer[0][0] │
# │ (Functional)        │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ efficientnetb0      │ (None, 7, 7,      │  4,049,571 │ input_layer[0][0] │
# │ (Functional)        │ 1280)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ densenet121         │ (None, 7, 7,      │  7,037,504 │ input_layer[0][0] │
# │ (Functional)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ xception            │ (None, 7, 7,      │ 20,861,480 │ input_layer[0][0] │
# │ (Functional)        │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 2048)      │          0 │ resnet50[0][0]    │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 1280)      │          0 │ efficientnetb0[0… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 1024)      │          0 │ densenet121[0][0] │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 2048)      │          0 │ xception[0][0]    │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │
# Epoch 49/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 46s 231ms/step - accuracy: 0.9992 - loss: 0.0083 - val_accuracy: 0.9406 - val_loss: 0.1893 - learning_rate: 6.2500e-06
# Epoch 50/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 46s 232ms/step - accuracy: 0.9991 - loss: 0.0074 - val_accuracy: 0.9406 - val_loss: 0.1897 - learning_rate: 6.2500e-06
# Epoch 51/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 47s 233ms/step - accuracy: 0.9991 - loss: 0.0099 - val_accuracy: 0.9406 - val_loss: 0.1894 - learning_rate: 6.2500e-06
# Epoch 52/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 46s 232ms/step - accuracy: 0.9991 - loss: 0.0073 - val_accuracy: 0.9406 - val_loss: 0.1928 - learning_rate: 6.2500e-06
# Epoch 53/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 46s 232ms/step - accuracy: 0.9996 - loss: 0.0069 - val_accuracy: 0.9413 - val_loss: 0.1951 - learning_rate: 6.2500e-06
# Epoch 54/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 46s 232ms/step - accuracy: 0.9992 - loss: 0.0079 - val_accuracy: 0.9413 - val_loss: 0.1953 - learning_rate: 3.1250e-06
# Epoch 55/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 46s 232ms/step - accuracy: 0.9987 - loss: 0.0081 - val_accuracy: 0.9394 - val_loss: 0.1957 - learning_rate: 3.1250e-06
# Epoch 56/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 46s 232ms/step - accuracy: 0.9998 - loss: 0.0061 - val_accuracy: 0.9394 - val_loss: 0.1944 - learning_rate: 3.1250e-06
# Epoch 57/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 46s 231ms/step - accuracy: 1.0000 - loss: 0.0058 - val_accuracy: 0.9413 - val_loss: 0.1948 - learning_rate: 3.1250e-06
# Epoch 58/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 46s 232ms/step - accuracy: 0.9971 - loss: 0.0086 - val_accuracy: 0.9406 - val_loss: 0.1910 - learning_rate: 3.1250e-06
# Epoch 59/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 46s 232ms/step - accuracy: 0.9996 - loss: 0.0053 - val_accuracy: 0.9413 - val_loss: 0.1908 - learning_rate: 1.5625e-06
# ✅ Test Accuracy (Val): 94.38%
# 📊 Classification Report:
#                precision    recall  f1-score   support
#
#   Chickenpox     0.9296    0.9900    0.9588       200
#       Eczema     0.9362    0.8800    0.9072       200
#        Lupus     0.9442    0.9300    0.9370       200
#      Measles     0.9752    0.9850    0.9801       200
#    Molluscum     0.9010    0.9100    0.9055       200
#    Monkeypox     0.9837    0.9050    0.9427       200
#       Normal     0.9851    0.9950    0.9900       200
#      Scabies     0.9009    0.9550    0.9272       200
#
#     accuracy                         0.9437      1600
#    macro avg     0.9445    0.9437    0.9436      1600
# weighted avg     0.9445    0.9437    0.9436      1600
#
# ✅ Cohen's Kappa Score: 0.9357
# 🔹 Sensitivity (Recall) for Chickenpox: 0.9900
# 🔹 Sensitivity (Recall) for Eczema: 0.8800
# 🔹 Sensitivity (Recall) for Lupus: 0.9300
# 🔹 Sensitivity (Recall) for Measles: 0.9850
# 🔹 Sensitivity (Recall) for Molluscum: 0.9100
# 🔹 Sensitivity (Recall) for Monkeypox: 0.9050
# 🔹 Sensitivity (Recall) for Normal: 0.9950
# 🔹 Sensitivity (Recall) for Scabies: 0.9550
#
# 📌 Averages:
# Micro Average    -> Precision: 0.9437, Recall: 0.9437, F1-score: 0.9437
# Macro Average    -> Precision: 0.9445, Recall: 0.9437, F1-score: 0.9436
# Weighted Average -> Precision: 0.9445, Recall: 0.9437, F1-score: 0.9436
#
# ================ BOOTSTRAP 95% CI (Val set) ================
# Accuracy: 0.9438 (95% CI: 0.9325 – 0.9550)
# Precision (macro): 0.9446 (95% CI: 0.9333 – 0.9554)
# Recall (macro): 0.9438 (95% CI: 0.9327 – 0.9549)
# F1 (macro): 0.9435 (95% CI: 0.9322 – 0.9546)
# Cohen's Kappa: 0.9357 (95% CI: 0.9228 – 0.9485)
# AUC (ovr-macro): 0.9974 (95% CI: 0.9965 – 0.9982)
#
# AUC (ovr-macro) on full Val: 0.9974
