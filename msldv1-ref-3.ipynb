# %%
# # This Python 3 environment comes with many helpful analytics libraries installed
# # It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# # For example, here's several helpful packages to load

# import numpy as np # linear algebra
# import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# # Input data files are available in the read-only "../input/" directory
# # For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

# import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))

# # You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# # You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# ============================================================
# FULL KAGGLE NOTEBOOK (Monkeypox multi-class)
# Ensemble CNN backbones + lightweight ViT block
# + Confusion Matrix + ROC
# + Bootstrap 95% Confidence Intervals for performance metrics
# ============================================================

import os
import random
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

from tensorflow.keras import layers, models, Input
from tensorflow.keras.applications import ResNet50, EfficientNetB0, DenseNet121, Xception
from tensorflow.keras.applications.resnet50 import preprocess_input as resnet_pre
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.utils import to_categorical

from sklearn.model_selection import train_test_split
from sklearn.metrics import (
    confusion_matrix, ConfusionMatrixDisplay,
    roc_curve, auc,
    classification_report, cohen_kappa_score,
    precision_recall_fscore_support, accuracy_score,
    roc_auc_score
)

# -----------------------------
# CONFIG
# -----------------------------
SEED = 42
IMAGE_SIZE = (224, 224)
NUM_CLASSES = 2
BATCH_SIZE = 32
EPOCHS = 100
SAMPLES_PER_CLASS = 1000
DATA_DIR = "/kaggle/input/msld-reff-3/MSLD"  # update if needed

# -----------------------------
# REPRODUCIBILITY
# -----------------------------
os.environ["PYTHONHASHSEED"] = str(SEED)
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

# -----------------------------
# LOAD & BALANCE DATA IN MEMORY
# -----------------------------
print("📦 Loading and sampling images per class...")

class_names = sorted([d for d in os.listdir(DATA_DIR) if os.path.isdir(os.path.join(DATA_DIR, d))])
print("Classes:", class_names)

all_images, all_labels_idx = [], []

for idx, class_name in enumerate(class_names):
    class_dir = os.path.join(DATA_DIR, class_name)
    image_files = [f for f in os.listdir(class_dir) if f.lower().endswith((".jpg", ".jpeg", ".png"))]

    if len(image_files) == 0:
        print(f"⚠️ No images found in: {class_dir}")
        continue

    selected = random.sample(image_files, min(SAMPLES_PER_CLASS, len(image_files)))

    for file in selected:
        img = load_img(os.path.join(class_dir, file), target_size=IMAGE_SIZE)
        img_array = img_to_array(img)
        img_array = resnet_pre(img_array)  # using ResNet preprocess for all (OK, but you can also match each backbone)
        all_images.append(img_array)
        all_labels_idx.append(idx)

all_images = np.array(all_images, dtype=np.float32)
all_labels_idx = np.array(all_labels_idx, dtype=np.int32)
all_labels_oh = to_categorical(all_labels_idx, num_classes=NUM_CLASSES)

print("Total images:", len(all_images))

# -----------------------------
# SPLIT (stratify must use class indices, NOT one-hot)
# -----------------------------
X_train, X_val, y_train, y_val, y_train_idx, y_val_idx = train_test_split(
    all_images, all_labels_oh, all_labels_idx,
    test_size=0.2,
    stratify=all_labels_idx,
    random_state=SEED
)

print("Train:", X_train.shape, y_train.shape)
print("Val  :", X_val.shape, y_val.shape)

# -----------------------------
# ViT BLOCK (small)
# -----------------------------
def create_vit_block(input_shape, projection_dim=64, num_heads=4, transformer_layers=4, patch_size=16):
    inputs = Input(shape=input_shape)

    # patch embedding
    num_patches = (input_shape[0] // patch_size) * (input_shape[1] // patch_size)
    x = layers.Conv2D(filters=projection_dim, kernel_size=patch_size, strides=patch_size, padding="valid")(inputs)
    x = layers.Reshape((num_patches, projection_dim))(x)

    # position embedding
    positions = tf.range(start=0, limit=num_patches, delta=1)
    pos_embed = layers.Embedding(input_dim=num_patches, output_dim=projection_dim)(positions)
    x = x + pos_embed

    # transformer encoder
    for _ in range(transformer_layers):
        x1 = layers.LayerNormalization(epsilon=1e-6)(x)
        attn = layers.MultiHeadAttention(num_heads=num_heads, key_dim=projection_dim)(x1, x1)
        x2 = layers.Add()([x, attn])

        x3 = layers.LayerNormalization(epsilon=1e-6)(x2)
        ffn = tf.keras.Sequential([
            layers.Dense(4 * projection_dim, activation="gelu"),
            layers.Dropout(0.1),
            layers.Dense(projection_dim),
        ])(x3)
        x = layers.Add()([x2, ffn])

    x = layers.LayerNormalization(epsilon=1e-6)(x)
    x = layers.GlobalAveragePooling1D()(x)
    return models.Model(inputs, x, name="ViT_Block")

# -----------------------------
# FEATURE EXTRACTION BACKBONES
# -----------------------------
input_layer = Input(shape=(224, 224, 3))

resnet = ResNet50(include_top=False, weights="imagenet", input_shape=(224, 224, 3))
efficientnet = EfficientNetB0(include_top=False, weights="imagenet", input_shape=(224, 224, 3))
densenet = DenseNet121(include_top=False, weights="imagenet", input_shape=(224, 224, 3))
xception = Xception(include_top=False, weights="imagenet", input_shape=(224, 224, 3))

for base in [resnet, efficientnet, densenet, xception]:
    base.trainable = False

def extract_features(base_model, x):
    x = base_model(x, training=False)
    x = layers.GlobalAveragePooling2D()(x)
    return x

resnet_feat = extract_features(resnet, input_layer)
efficientnet_feat = extract_features(efficientnet, input_layer)
densenet_feat = extract_features(densenet, input_layer)
xception_feat = extract_features(xception, input_layer)

vit_feat = create_vit_block((224, 224, 3))(input_layer)

# -----------------------------
# FUSION + CLASSIFIER
# -----------------------------
combined = layers.Concatenate()([resnet_feat, efficientnet_feat, densenet_feat, xception_feat, vit_feat])

x = layers.Dense(512, activation="relu")(combined)
x = layers.Dropout(0.5)(x)
output = layers.Dense(NUM_CLASSES, activation="softmax")(x)

model = models.Model(inputs=input_layer, outputs=output)
model.compile(
    optimizer=tf.keras.optimizers.Adam(1e-4),
    loss="categorical_crossentropy",
    metrics=["accuracy"]
)

model.summary()

# -----------------------------
# TRAIN
# -----------------------------
callbacks = [
    tf.keras.callbacks.EarlyStopping(monitor="val_accuracy", patience=12, restore_best_weights=True),
    tf.keras.callbacks.ReduceLROnPlateau(monitor="val_loss", factor=0.5, patience=5, min_lr=1e-6)
]

history = model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    callbacks=callbacks,
    verbose=1
)

# -----------------------------
# PLOT ACCURACY & LOSS
# -----------------------------
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history.history["accuracy"], label="Train")
plt.plot(history.history["val_accuracy"], label="Validation")
plt.title("Accuracy")
plt.legend()
plt.grid(True)

plt.subplot(1, 2, 2)
plt.plot(history.history["loss"], label="Train")
plt.plot(history.history["val_loss"], label="Validation")
plt.title("Loss")
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# -----------------------------
# EVALUATION (VAL AS TEST)
# -----------------------------
test_loss, test_acc = model.evaluate(X_val, y_val, batch_size=32, verbose=0)
print(f"✅ Test Accuracy (Val): {test_acc*100:.2f}%")

y_pred = model.predict(X_val, batch_size=32, verbose=0)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true_classes = np.argmax(y_val, axis=1)

# -----------------------------
# CONFUSION MATRIX
# -----------------------------
cm = confusion_matrix(y_true_classes, y_pred_classes)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names)
disp.plot(xticks_rotation=45, cmap="Blues")
plt.title("Confusion Matrix")
plt.tight_layout()
plt.show()

# -----------------------------
# ROC CURVE (one-vs-rest per class)
# -----------------------------
plt.figure(figsize=(10, 7))
for i in range(NUM_CLASSES):
    fpr, tpr, _ = roc_curve(y_val[:, i], y_pred[:, i])
    auc_score = auc(fpr, tpr)
    plt.plot(fpr, tpr, label=f"{class_names[i]} (AUC={auc_score:.2f})")

plt.plot([0, 1], [0, 1], "k--")
plt.xlabel("FPR")
plt.ylabel("TPR")
plt.title("ROC Curve (OvR)")
plt.legend()
plt.grid(True)
plt.show()

# -----------------------------
# CLASSIFICATION REPORT + KAPPA + SENSITIVITY
# -----------------------------
report = classification_report(y_true_classes, y_pred_classes, target_names=class_names, digits=4)
print("📊 Classification Report:\n", report)

kappa = cohen_kappa_score(y_true_classes, y_pred_classes)
print(f"✅ Cohen's Kappa Score: {kappa:.4f}")

sensitivity_per_class = precision_recall_fscore_support(y_true_classes, y_pred_classes, average=None)[1]
for idx, cls in enumerate(class_names):
    print(f"🔹 Sensitivity (Recall) for {cls}: {sensitivity_per_class[idx]:.4f}")

precision_micro, recall_micro, f1_micro, _ = precision_recall_fscore_support(
    y_true_classes, y_pred_classes, average="micro"
)
precision_macro, recall_macro, f1_macro, _ = precision_recall_fscore_support(
    y_true_classes, y_pred_classes, average="macro"
)
precision_weighted, recall_weighted, f1_weighted, _ = precision_recall_fscore_support(
    y_true_classes, y_pred_classes, average="weighted"
)

print("\n📌 Averages:")
print(f"Micro Average    -> Precision: {precision_micro:.4f}, Recall: {recall_micro:.4f}, F1-score: {f1_micro:.4f}")
print(f"Macro Average    -> Precision: {precision_macro:.4f}, Recall: {recall_macro:.4f}, F1-score: {f1_macro:.4f}")
print(f"Weighted Average -> Precision: {precision_weighted:.4f}, Recall: {recall_weighted:.4f}, F1-score: {f1_weighted:.4f}")

# ============================================================
# BOOTSTRAP 95% CONFIDENCE INTERVALS
# ============================================================
def bootstrap_ci(y_true_cls, y_prob, n_boot=2000, ci=95, seed=42):
    """
    y_true_cls: (N,) int labels
    y_prob    : (N, C) predicted probabilities
    Returns dict of metric -> (mean, low, high)
    """
    rng = np.random.default_rng(seed)
    n = len(y_true_cls)

    acc_list = []
    prec_macro_list = []
    rec_macro_list = []
    f1_macro_list = []
    kappa_list = []
    auc_ovr_macro_list = []

    # Convert true labels to one-hot for AUC
    y_true_oh = to_categorical(y_true_cls, num_classes=y_prob.shape[1])

    for _ in range(n_boot):
        idx = rng.integers(0, n, size=n)  # sample with replacement
        yt = y_true_cls[idx]
        yp = y_prob[idx]
        yp_cls = np.argmax(yp, axis=1)

        acc_list.append(accuracy_score(yt, yp_cls))

        p, r, f1, _ = precision_recall_fscore_support(yt, yp_cls, average="macro", zero_division=0)
        prec_macro_list.append(p)
        rec_macro_list.append(r)
        f1_macro_list.append(f1)

        kappa_list.append(cohen_kappa_score(yt, yp_cls))

        # AUC OvR macro (needs at least one sample per class in this bootstrap draw)
        # Handle rare failure safely:
        try:
            yt_oh = to_categorical(yt, num_classes=yp.shape[1])
            auc_ovr_macro_list.append(
                roc_auc_score(yt_oh, yp, multi_class="ovr", average="macro")
            )
        except Exception:
            # skip this draw if AUC cannot be computed
            pass

    def ci_bounds(values):
        values = np.array(values, dtype=np.float64)
        mean = float(np.mean(values))
        alpha = (100 - ci) / 2
        low = float(np.percentile(values, alpha))
        high = float(np.percentile(values, 100 - alpha))
        return mean, low, high

    out = {
        "Accuracy": ci_bounds(acc_list),
        "Precision (macro)": ci_bounds(prec_macro_list),
        "Recall (macro)": ci_bounds(rec_macro_list),
        "F1 (macro)": ci_bounds(f1_macro_list),
        "Cohen's Kappa": ci_bounds(kappa_list),
    }
    if len(auc_ovr_macro_list) > 50:
        out["AUC (ovr-macro)"] = ci_bounds(auc_ovr_macro_list)
    else:
        out["AUC (ovr-macro)"] = ("NA", "NA", "NA")

    return out

ci_results = bootstrap_ci(y_true_classes, y_pred, n_boot=2000, ci=95, seed=SEED)

print("\n================ BOOTSTRAP 95% CI (Val set) ================")
for k, v in ci_results.items():
    if v[0] == "NA":
        print(f"{k}: NA (not enough valid bootstrap samples)")
    else:
        mean, low, high = v
        print(f"{k}: {mean:.4f} (95% CI: {low:.4f} – {high:.4f})")

# Also print the single-shot AUC (ovr-macro) on full val (not bootstrap)
try:
    auc_full = roc_auc_score(y_val, y_pred, multi_class="ovr", average="macro")
    print(f"\nAUC (ovr-macro) on full Val: {auc_full:.4f}")
except Exception as e:
    print("\nAUC (ovr-macro) on full Val: could not compute ->", e)
# Out:
# 2026-02-26 20:39:39.125289: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1772138379.298353      55 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1772138379.352766      55 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1772138379.780944      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1772138379.780989      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1772138379.780992      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1772138379.780995      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 📦 Loading and sampling images per class...
# Classes: ['Monkeypox', 'Others']
# Total images: 2000
# Train: (1600, 224, 224, 3) (1600, 2)
# Val  : (400, 224, 224, 3) (400, 2)
# I0000 00:00:1772138412.630356      55 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15511 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 4s 0us/step
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29084464/29084464 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83683744/83683744 ━━━━━━━━━━━━━━━━━━━━ 4s 0us/step
# Model: "functional_4"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 224, 224,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ resnet50            │ (None, 7, 7,      │ 23,587,712 │ input_layer[0][0] │
# │ (Functional)        │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ efficientnetb0      │ (None, 7, 7,      │  4,049,571 │ input_layer[0][0] │
# │ (Functional)        │ 1280)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ densenet121         │ (None, 7, 7,      │  7,037,504 │ input_layer[0][0] │
# │ (Functional)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ xception            │ (None, 7, 7,      │ 20,861,480 │ input_layer[0][0] │
# │ (Functional)        │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 2048)      │          0 │ resnet50[0][0]    │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 1280)      │          0 │ efficientnetb0[0… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 1024)      │          0 │ densenet121[0][0] │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 2048)      │          0 │ xception[0][0]    │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ ViT_Block           │ (None, 64)        │    448,192 │ input_layer[0][0] │
# │ (Functional)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 6464)      │          0 │ global_average_p… │
# │ (Concatenate)       │                   │            │ global_average_p… │
# │                     │                   │            │ global_average_p… │
# │                     │                   │            │ global_average_p… │
# │                     │                   │            │ ViT_Block[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_8 (Dense)     │ (None, 512)       │  3,310,080 │ concatenate[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_8 (Dropout) │ (None, 512)       │          0 │ dense_8[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_9 (Dense)     │ (None, 2)         │      1,026 │ dropout_8[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 59,295,565 (226.19 MB)
#  Trainable params: 3,759,298 (14.34 MB)
#  Non-trainable params: 55,536,267 (211.85 MB)
# Epoch 1/100
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1772138470.964916     122 service.cc:152] XLA service 0x7c681c0a5580 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1772138470.964958     122 service.cc:160]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1772138480.078536     122 cuda_dnn.cc:529] Loaded cuDNN version 91002
# I0000 00:00:1772138518.737960     122 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 155s 1s/step - accuracy: 0.5787 - loss: 3.4163 - val_accuracy: 0.7750 - val_loss: 0.7283 - learning_rate: 1.0000e-04
# Epoch 2/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 12s 238ms/step - accuracy: 0.7448 - loss: 1.4954 - val_accuracy: 0.8200 - val_loss: 0.7002 - learning_rate: 1.0000e-04
# Epoch 3/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 12s 239ms/step - accuracy: 0.8197 - loss: 0.7716 - val_accuracy: 0.8575 - val_loss: 0.3773 - learning_rate: 1.0000e-04
# Epoch 4/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 12s 240ms/step - accuracy: 0.8329 - loss: 0.5968 - val_accuracy: 0.8750 - val_loss: 0.3251 - learning_rate: 1.0000e-04
# Epoch 5/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 12s 240ms/step - accuracy: 0.8536 - loss: 0.5272 - val_accuracy: 0.8800 - val_loss: 0.3391 - learning_rate: 1.0000e-04
# Epoch 6/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 11s 230ms/step - accuracy: 0.8805 - loss: 0.4641 - val_accuracy: 0.8550 - val_loss: 0.2972 - learning_rate: 1.0000e-04
# Epoch 7/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 12s 239ms/step - accuracy: 0.8992 - loss: 0.4068 - val_accuracy: 0.8925 - val_loss: 0.3315 - learning_rate: 1.0000e-04
# Epoch 8/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 12s 240ms/step - accuracy: 0.9204 - loss: 0.2626 - val_accuracy: 0.9050 - val_loss: 0.2487 - learning_rate: 1.0000e-04
# Epoch 9/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 11s 229ms/step - accuracy: 0.9215 - loss: 0.2416 - val_accuracy: 0.8975 - val_loss: 0.2384 - learning_rate: 1.0000e-04
# Epoch 10/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 12s 239ms/step - accuracy: 0.9339 - loss: 0.1940 - val_accuracy: 0.9075 - val_loss: 0.2422 - learning_rate: 1.0000e-04
# Epoch 11/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 11s 228ms/step - accuracy: 0.9428 - loss: 0.1747 - val_accuracy: 0.9000 - val_loss: 0.2856 - learning_rate: 1.0000e-04
# Epoch 12/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 11s 229ms/step - accuracy: 0.9656 - loss: 0.1270 - val_accuracy: 0.8775 - val_loss: 0.2697 - learning_rate: 1.0000e-04
# Epoch 13/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 11s 230ms/step - accuracy: 0.9513 - loss: 0.1415 - val_accuracy: 0.9050 - val_loss: 0.2435 - learning_rate: 1.0000e-04
# Epoch 14/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 11s 229ms/step - accuracy: 0.9611 - loss: 0.1056 - val_accuracy: 0.9075 - val_loss: 0.2126 - learning_rate: 1.0000e-04
# Epoch 15/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 11s 229ms/step - accuracy: 0.9789 - loss: 0.0827 - val_accuracy: 0.8975 - val_loss: 0.2346 - learning_rate: 1.0000e-04
# Epoch 16/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 12s 240ms/step - accuracy: 0.9735 - loss: 0.0776 - val_accuracy: 0.9150 - val_loss: 0.2088 - learning_rate: 1.0000e-04
# Epoch 17/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 12s 239ms/step - accuracy: 0.9786 - loss: 0.0778 - val_accuracy: 0.9175 - val_loss: 0.2236 - learning_rate: 1.0000e-04
# Epoch 18/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 12s 240ms/step - accuracy: 0.9686 - loss: 0.1016 - val_accuracy: 0.9275 - val_loss: 0.2111 - learning_rate: 1.0000e-04
# Epoch 19/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 11s 229ms/step - accuracy: 0.9716 - loss: 0.0843 - val_accuracy: 0.9225 - val_loss: 0.2212 - learning_rate: 1.0000e-04
# Epoch 20/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 12s 240ms/step - accuracy: 0.9906 - loss: 0.0477 - val_accuracy: 0.9300 - val_loss: 0.2000 - learning_rate: 1.0000e-04
# Epoch 21/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 11s 230ms/step - accuracy: 0.9803 - loss: 0.0697 - val_accuracy: 0.9275 - val_loss: 0.2327 - learning_rate: 1.0000e-04
# Epoch 22/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 12s 240ms/step - accuracy: 0.9852 - loss: 0.0459 - val_accuracy: 0.9450 - val_loss: 0.2060 - learning_rate: 1.0000e-04
# Epoch 23/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 11s 229ms/step - accuracy: 0.9804 - loss: 0.0579 - val_accuracy: 0.9200 - val_loss: 0.2324 - learning_rate: 1.0000e-04
# Epoch 24/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 11s 229ms/step - accuracy: 0.9813 - loss: 0.0584 - val_accuracy: 0.9125 - val_loss: 0.2606 - learning_rate: 1.0000e-04
# Epoch 25/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 11s 230ms/step - accuracy: 0.9691 - loss: 0.0780 - val_accuracy: 0.9200 - val_loss: 0.2273 - learning_rate: 1.0000e-04
# Epoch 26/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 11s 229ms/step - accuracy: 0.9824 - loss: 0.0542 - val_accuracy: 0.9350 - val_loss: 0.2057 - learning_rate: 5.0000e-05
# Epoch 27/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 11s 230ms/step - accuracy: 0.9882 - loss: 0.0374 - val_accuracy: 0.9250 - val_loss: 0.1948 - learning_rate: 5.0000e-05
# Epoch 28/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 11s 230ms/step - accuracy: 0.9894 - loss: 0.0370 - val_accuracy: 0.9325 - val_loss: 0.1938 - learning_rate: 5.0000e-05
# Epoch 29/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 11s 230ms/step - accuracy: 0.9882 - loss: 0.0435 - val_accuracy: 0.9375 - val_loss: 0.1801 - learning_rate: 5.0000e-05
# Epoch 30/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 11s 229ms/step - accuracy: 0.9926 - loss: 0.0262 - val_accuracy: 0.9450 - val_loss: 0.1975 - learning_rate: 5.0000e-05
# Epoch 31/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 11s 229ms/step - accuracy: 0.9970 - loss: 0.0212 - val_accuracy: 0.9425 - val_loss: 0.1886 - learning_rate: 5.0000e-05
# Epoch 32/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 11s 230ms/step - accuracy: 0.9975 - loss: 0.0212 - val_accuracy: 0.9300 - val_loss: 0.2053 - learning_rate: 5.0000e-05
# Epoch 33/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 11s 230ms/step - accuracy: 0.9955 - loss: 0.0239 - val_accuracy: 0.9350 - val_loss: 0.2010 - learning_rate: 5.0000e-05
# Epoch 34/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 11s 229ms/step - accuracy: 0.9943 - loss: 0.0246 - val_accuracy: 0.9275 - val_loss: 0.2025 - learning_rate: 5.0000e-05
# ✅ Test Accuracy (Val): 94.50%
# 📊 Classification Report:
#                precision    recall  f1-score   support
#
#    Monkeypox     0.9734    0.9150    0.9433       200
#       Others     0.9198    0.9750    0.9466       200
#
#     accuracy                         0.9450       400
#    macro avg     0.9466    0.9450    0.9450       400
# weighted avg     0.9466    0.9450    0.9450       400
#
# ✅ Cohen's Kappa Score: 0.8900
# 🔹 Sensitivity (Recall) for Monkeypox: 0.9150
# 🔹 Sensitivity (Recall) for Others: 0.9750
#
# 📌 Averages:
# Micro Average    -> Precision: 0.9450, Recall: 0.9450, F1-score: 0.9450
# Macro Average    -> Precision: 0.9466, Recall: 0.9450, F1-score: 0.9450
# Weighted Average -> Precision: 0.9466, Recall: 0.9450, F1-score: 0.9450
#
# ================ BOOTSTRAP 95% CI (Val set) ================
# Accuracy: 0.9449 (95% CI: 0.9200 – 0.9675)
# Precision (macro): 0.9465 (95% CI: 0.9223 – 0.9677)
# Recall (macro): 0.9449 (95% CI: 0.9211 – 0.9673)
# F1 (macro): 0.9447 (95% CI: 0.9199 – 0.9674)
# Cohen's Kappa: 0.8895 (95% CI: 0.8402 – 0.9349)
# AUC (ovr-macro): 0.9764 (95% CI: 0.9607 – 0.9893)
#
# AUC (ovr-macro) on full Val: 0.9763

# %%
# ============================================================
# ✅ FULL KAGGLE NOTEBOOK (MSID / Monkeypox 4-class)
# ✅ Ensemble CNN backbones + lightweight ViT block
# ✅ 5-FOLD STRATIFIED CV
# ✅ Two-stage training (warm-up + fine-tune)
# ✅ Confusion Matrix + ROC + Report + Kappa + Sensitivity
# ✅ Bootstrap 95% CI per fold
#
# FIXED ISSUES:
# 1) Name collision error: solved by NOT using input_tensor=
# 2) HTTP 403 on EfficientNet weights: handled with safe loader fallback
# ============================================================

import os, random
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

from tensorflow.keras import layers, models, Input
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.utils import to_categorical

from tensorflow.keras.applications import ResNet50, DenseNet121, Xception, EfficientNetB0

from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import (
    confusion_matrix, ConfusionMatrixDisplay,
    roc_curve, auc,
    classification_report, cohen_kappa_score,
    precision_recall_fscore_support, accuracy_score,
    roc_auc_score
)
from sklearn.utils.class_weight import compute_class_weight

# -----------------------------
# CONFIG
# -----------------------------
SEED = 42
IMAGE_SIZE = (224, 224)
NUM_CLASSES = 2
BATCH_SIZE = 32

# Stage A warmup
EPOCHS_WARMUP = 10
LR_WARMUP = 1e-4

# Stage B finetune
EPOCHS_FINETUNE = 25
LR_FINETUNE = 1e-5
UNFREEZE_LAST_N = 30

# Data
SAMPLES_PER_CLASS = 1000  # set None to use all
DATA_DIR = "/kaggle/input/msld-reff-3/MSLD"

# CV + CI
N_SPLITS = 5
BOOT_N = 2000
CI_LEVEL = 95

# Backbones toggles (to avoid 403 / memory)
USE_EFFICIENTNET = False   # ✅ safest: set False to avoid 403
USE_XCEPTION     = True

# -----------------------------
# REPRODUCIBILITY
# -----------------------------
os.environ["PYTHONHASHSEED"] = str(SEED)
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

# -----------------------------
# LOAD DATA (NO AUGMENTATION HERE)
# -----------------------------
print("📦 Loading images...")

class_names = sorted([d for d in os.listdir(DATA_DIR) if os.path.isdir(os.path.join(DATA_DIR, d))])
print("Classes:", class_names)
assert len(class_names) == NUM_CLASSES, f"Found {len(class_names)} classes, expected {NUM_CLASSES}"

X_list, y_idx_list = [], []

for cls_idx, cls in enumerate(class_names):
    cls_dir = os.path.join(DATA_DIR, cls)
    files = [f for f in os.listdir(cls_dir) if f.lower().endswith((".jpg", ".jpeg", ".png"))]
    if len(files) == 0:
        raise ValueError(f"No images found in {cls_dir}")

    if SAMPLES_PER_CLASS is not None:
        files = random.sample(files, min(SAMPLES_PER_CLASS, len(files)))

    for f in files:
        img = load_img(os.path.join(cls_dir, f), target_size=IMAGE_SIZE)
        arr = img_to_array(img).astype(np.float32) / 255.0
        X_list.append(arr)
        y_idx_list.append(cls_idx)

X = np.stack(X_list, axis=0)
y_idx = np.array(y_idx_list, dtype=np.int32)

print("Total images:", len(X))
print("Class counts:", {class_names[i]: int(np.sum(y_idx == i)) for i in range(NUM_CLASSES)})

# -----------------------------
# TRAIN-ONLY AUGMENTATION
# -----------------------------
train_aug = tf.keras.Sequential(
    [
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(0.08),
        layers.RandomZoom(0.10),
        layers.RandomContrast(0.10),
    ],
    name="train_augmentation"
)

# -----------------------------
# LIGHTWEIGHT ViT BLOCK
# -----------------------------
def create_vit_block(input_shape, projection_dim=64, num_heads=4, transformer_layers=3, patch_size=16):
    inputs = Input(shape=input_shape)

    num_patches = (input_shape[0] // patch_size) * (input_shape[1] // patch_size)
    x = layers.Conv2D(projection_dim, kernel_size=patch_size, strides=patch_size, padding="valid")(inputs)
    x = layers.Reshape((num_patches, projection_dim))(x)

    positions = tf.range(start=0, limit=num_patches, delta=1)
    pos_embed = layers.Embedding(input_dim=num_patches, output_dim=projection_dim)(positions)
    x = x + pos_embed

    for _ in range(transformer_layers):
        x1 = layers.LayerNormalization(epsilon=1e-6)(x)
        attn = layers.MultiHeadAttention(num_heads=num_heads, key_dim=projection_dim)(x1, x1)
        x2 = layers.Add()([x, attn])

        x3 = layers.LayerNormalization(epsilon=1e-6)(x2)
        ffn = tf.keras.Sequential(
            [
                layers.Dense(4 * projection_dim, activation="gelu"),
                layers.Dropout(0.1),
                layers.Dense(projection_dim),
            ]
        )(x3)
        x = layers.Add()([x2, ffn])

    x = layers.LayerNormalization(epsilon=1e-6)(x)
    x = layers.GlobalAveragePooling1D()(x)
    return models.Model(inputs, x, name="ViT_Block")

# -----------------------------
# SAFE BACKBONE LOADER (handles HTTP 403)
# -----------------------------
def safe_backbone(constructor, name, input_shape=(224,224,3), prefer_imagenet=True):
    """
    Try weights='imagenet'. If download fails (403), fall back to weights=None.
    """
    if prefer_imagenet:
        try:
            return constructor(include_top=False, weights="imagenet", input_shape=input_shape, name=name)
        except Exception as e:
            print(f"⚠️ Could not load ImageNet weights for {name}: {e}")
            print(f"➡️ Falling back to weights=None for {name}")
    return constructor(include_top=False, weights=None, input_shape=input_shape, name=name)

# -----------------------------
# BUILD MODEL (PER FOLD)
# -----------------------------
def build_model(num_classes=NUM_CLASSES, label_smoothing=0.05):
    inp = Input(shape=(224, 224, 3), name="input")
    x_aug = train_aug(inp)

    # ✅ Build without input_tensor to avoid name collisions
    resnet = safe_backbone(ResNet50,   "ResNet50_backbone",   prefer_imagenet=True)
    dense  = safe_backbone(DenseNet121,"DenseNet121_backbone",prefer_imagenet=True)

    backbones = [resnet, dense]

    if USE_EFFICIENTNET:
        eff = safe_backbone(EfficientNetB0, "EffNetB0_backbone", prefer_imagenet=True)
        backbones.append(eff)

    if USE_XCEPTION:
        xcep = safe_backbone(Xception, "Xception_backbone", prefer_imagenet=True)
        backbones.append(xcep)

    # Freeze warmup
    for b in backbones:
        b.trainable = False

    def feat(backbone, x):
        y = backbone(x, training=False)
        y = layers.GlobalAveragePooling2D()(y)
        return y

    feats = [feat(b, x_aug) for b in backbones]

    vit = create_vit_block((224, 224, 3), projection_dim=64, num_heads=4, transformer_layers=3, patch_size=16)
    feats.append(vit(x_aug))

    fused = layers.Concatenate(name="fusion")(feats)

    z = layers.BatchNormalization()(fused)
    z = layers.Dense(1024, activation="relu")(z)
    z = layers.Dropout(0.4)(z)
    z = layers.Dense(256, activation="relu")(z)
    z = layers.Dropout(0.3)(z)
    out = layers.Dense(num_classes, activation="softmax")(z)

    model = models.Model(inp, out, name="EnsembleCNN_ViT")

    loss_fn = tf.keras.losses.CategoricalCrossentropy(label_smoothing=label_smoothing)
    model.compile(
        optimizer=tf.keras.optimizers.Adam(LR_WARMUP),
        loss=loss_fn,
        metrics=["accuracy"]
    )
    return model, tuple(backbones)

def unfreeze_last_n(backbones, n=30):
    for b in backbones:
        b.trainable = True
        for layer in b.layers[:-n]:
            layer.trainable = False
        # keep BN frozen for stability
        for layer in b.layers:
            if isinstance(layer, layers.BatchNormalization):
                layer.trainable = False

# -----------------------------
# BOOTSTRAP CI
# -----------------------------
def bootstrap_ci(y_true_cls, y_prob, n_boot=2000, ci=95, seed=42):
    rng = np.random.default_rng(seed)
    n = len(y_true_cls)

    acc_list, prec_list, rec_list, f1_list, kappa_list, auc_list = [], [], [], [], [], []

    for _ in range(n_boot):
        idx = rng.integers(0, n, size=n)
        yt = y_true_cls[idx]
        yp = y_prob[idx]
        yp_cls = np.argmax(yp, axis=1)

        acc_list.append(accuracy_score(yt, yp_cls))
        p, r, f1, _ = precision_recall_fscore_support(yt, yp_cls, average="macro", zero_division=0)
        prec_list.append(p); rec_list.append(r); f1_list.append(f1)
        kappa_list.append(cohen_kappa_score(yt, yp_cls))

        try:
            yt_oh = to_categorical(yt, num_classes=yp.shape[1])
            auc_list.append(roc_auc_score(yt_oh, yp, multi_class="ovr", average="macro"))
        except Exception:
            pass

    def bounds(vals):
        vals = np.array(vals, dtype=np.float64)
        alpha = (100 - ci) / 2
        return float(np.mean(vals)), float(np.percentile(vals, alpha)), float(np.percentile(vals, 100 - alpha))

    out = {
        "Accuracy": bounds(acc_list),
        "Precision (macro)": bounds(prec_list),
        "Recall (macro)": bounds(rec_list),
        "F1 (macro)": bounds(f1_list),
        "Cohen's Kappa": bounds(kappa_list),
    }
    out["AUC (ovr-macro)"] = bounds(auc_list) if len(auc_list) > 50 else ("NA", "NA", "NA")
    return out

# -----------------------------
# 5-FOLD STRATIFIED CV
# -----------------------------
skf = StratifiedKFold(n_splits=N_SPLITS, shuffle=True, random_state=SEED)
fold_metrics = []

for fold, (train_idx, val_idx) in enumerate(skf.split(X, y_idx), start=1):
    print(f"\n\n====================== FOLD {fold}/{N_SPLITS} ======================")

    X_train, X_val = X[train_idx], X[val_idx]
    y_train_idx, y_val_idx = y_idx[train_idx], y_idx[val_idx]
    print("Val class counts:", {class_names[i]: int(np.sum(y_val_idx == i)) for i in range(NUM_CLASSES)})

    y_train = to_categorical(y_train_idx, num_classes=NUM_CLASSES)
    y_val = to_categorical(y_val_idx, num_classes=NUM_CLASSES)

    cw = compute_class_weight(class_weight="balanced", classes=np.arange(NUM_CLASSES), y=y_train_idx)
    class_weight = {i: float(cw[i]) for i in range(NUM_CLASSES)}
    print("Class weights:", class_weight)

    tf.keras.backend.clear_session()
    model, backbones = build_model()

    callbacks = [
        tf.keras.callbacks.EarlyStopping(monitor="val_accuracy", patience=8, restore_best_weights=True),
        tf.keras.callbacks.ReduceLROnPlateau(monitor="val_loss", factor=0.5, patience=3, min_lr=1e-6),
    ]

    # Stage A warmup
    hist1 = model.fit(
        X_train, y_train,
        validation_data=(X_val, y_val),
        epochs=EPOCHS_WARMUP,
        batch_size=BATCH_SIZE,
        callbacks=callbacks,
        class_weight=class_weight,
        verbose=1
    )

    # Stage B fine-tune
    unfreeze_last_n(backbones, n=UNFREEZE_LAST_N)
    model.compile(
        optimizer=tf.keras.optimizers.Adam(LR_FINETUNE),
        loss=tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.05),
        metrics=["accuracy"]
    )
    hist2 = model.fit(
        X_train, y_train,
        validation_data=(X_val, y_val),
        epochs=EPOCHS_FINETUNE,
        batch_size=BATCH_SIZE,
        callbacks=callbacks,
        class_weight=class_weight,
        verbose=1
    )

    # Evaluate
    loss, acc = model.evaluate(X_val, y_val, batch_size=32, verbose=0)
    print(f"✅ Fold {fold} Accuracy: {acc*100:.2f}%")

    y_prob = model.predict(X_val, batch_size=32, verbose=0)
    y_pred = np.argmax(y_prob, axis=1)
    y_true = y_val_idx

    # Confusion matrix
    cm = confusion_matrix(y_true, y_pred)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names)
    disp.plot(xticks_rotation=45, cmap="Blues")
    plt.title(f"Fold {fold} Confusion Matrix")
    plt.tight_layout()
    plt.show()

    # ROC
    plt.figure(figsize=(10,7))
    for i in range(NUM_CLASSES):
        fpr, tpr, _ = roc_curve(y_val[:, i], y_prob[:, i])
        auc_score = auc(fpr, tpr)
        plt.plot(fpr, tpr, label=f"{class_names[i]} (AUC={auc_score:.2f})")
    plt.plot([0,1],[0,1],"k--")
    plt.xlabel("FPR"); plt.ylabel("TPR")
    plt.title(f"Fold {fold} ROC (OvR)")
    plt.legend(); plt.grid(True)
    plt.show()

    # Report + Kappa + Sensitivity
    print("📊 Classification Report:\n",
          classification_report(y_true, y_pred, target_names=class_names, digits=4))

    kappa = cohen_kappa_score(y_true, y_pred)
    print(f"✅ Fold {fold} Cohen's Kappa: {kappa:.4f}")

    sens = precision_recall_fscore_support(y_true, y_pred, average=None, zero_division=0)[1]
    for i, cls in enumerate(class_names):
        print(f"🔹 Sensitivity (Recall) for {cls}: {sens[i]:.4f}")

    # Bootstrap CI
    ci_results = bootstrap_ci(y_true, y_prob, n_boot=BOOT_N, ci=CI_LEVEL, seed=SEED + fold)
    print(f"\n================ BOOTSTRAP {CI_LEVEL}% CI (Fold {fold}) ================")
    for k, v in ci_results.items():
        if v[0] == "NA":
            print(f"{k}: NA")
        else:
            m, lo, hi = v
            print(f"{k}: {m:.4f} ({CI_LEVEL}% CI: {lo:.4f} – {hi:.4f})")

    # Store fold metrics
    prec_macro, rec_macro, f1_macro, _ = precision_recall_fscore_support(
        y_true, y_pred, average="macro", zero_division=0
    )
    try:
        auc_macro = roc_auc_score(y_val, y_prob, multi_class="ovr", average="macro")
    except Exception:
        auc_macro = np.nan

    fold_metrics.append({
        "fold": fold,
        "acc": float(accuracy_score(y_true, y_pred)),
        "prec_macro": float(prec_macro),
        "rec_macro": float(rec_macro),
        "f1_macro": float(f1_macro),
        "kappa": float(kappa),
        "auc_macro": float(auc_macro) if np.isfinite(auc_macro) else np.nan
    })

# -----------------------------
# FINAL SUMMARY
# -----------------------------
import pandas as pd
dfm = pd.DataFrame(fold_metrics)

print("\n\n==================== 5-FOLD CV SUMMARY ====================")
for col in ["acc", "prec_macro", "rec_macro", "f1_macro", "kappa", "auc_macro"]:
    vals = dfm[col].values.astype(float)
    print(f"{col:12s}: {np.nanmean(vals):.4f} ± {np.nanstd(vals):.4f}")

print("\nPer-fold table:")
print(dfm)

print("\n✅ NOTE:")
print("If you want higher accuracy, try: UNFREEZE_LAST_N=60 and EPOCHS_FINETUNE=50")
print("If Kaggle memory is low, keep USE_EFFICIENTNET=False (default) and/or USE_XCEPTION=False.")
# Out:
# 📦 Loading images...
# Classes: ['Monkeypox', 'Others']
# Total images: 2000
# Class counts: {'Monkeypox': 1000, 'Others': 1000}
#
#
# ====================== FOLD 1/5 ======================
# Val class counts: {'Monkeypox': 200, 'Others': 200}
# Class weights: {0: 1.0, 1: 1.0}
# Epoch 1/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 65s 573ms/step - accuracy: 0.6990 - loss: 0.6778 - val_accuracy: 0.8000 - val_loss: 0.4913 - learning_rate: 1.0000e-04
# Epoch 2/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 17s 337ms/step - accuracy: 0.8444 - loss: 0.4078 - val_accuracy: 0.8700 - val_loss: 0.4162 - learning_rate: 1.0000e-04
# Epoch 3/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 17s 337ms/step - accuracy: 0.8915 - loss: 0.3272 - val_accuracy: 0.9000 - val_loss: 0.3561 - learning_rate: 1.0000e-04
# Epoch 4/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 16s 329ms/step - accuracy: 0.9102 - loss: 0.3015 - val_accuracy: 0.8975 - val_loss: 0.3359 - learning_rate: 1.0000e-04
# Epoch 5/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 17s 337ms/step - accuracy: 0.9328 - loss: 0.2605 - val_accuracy: 0.9175 - val_loss: 0.3019 - learning_rate: 1.0000e-04
# Epoch 6/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 17s 336ms/step - accuracy: 0.9404 - loss: 0.2468 - val_accuracy: 0.9300 - val_loss: 0.2797 - learning_rate: 1.0000e-04
# Epoch 7/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 16s 328ms/step - accuracy: 0.9627 - loss: 0.2240 - val_accuracy: 0.9300 - val_loss: 0.2701 - learning_rate: 1.0000e-04
# Epoch 8/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 17s 336ms/step - accuracy: 0.9535 - loss: 0.2375 - val_accuracy: 0.9350 - val_loss: 0.2722 - learning_rate: 1.0000e-04
# Epoch 9/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 16s 328ms/step - accuracy: 0.9680 - loss: 0.2153 - val_accuracy: 0.9300 - val_loss: 0.2586 - learning_rate: 1.0000e-04
# Epoch 10/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 17s 335ms/step - accuracy: 0.9619 - loss: 0.2142 - val_accuracy: 0.9450 - val_loss: 0.2410 - learning_rate: 1.0000e-04
# Epoch 1/25
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 65s 583ms/step - accuracy: 0.9641 - loss: 0.2157 - val_accuracy: 0.9375 - val_loss: 0.2659 - learning_rate: 1.0000e-05
# Epoch 2/25
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 19s 387ms/step - accuracy: 0.9734 - loss: 0.2080 - val_accuracy: 0.9425 - val_loss: 0.2475 - learning_rate: 1.0000e-05
# Epoch 3/25
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 19s 387ms/step - accuracy: 0.9798 - loss: 0.1882 - val_accuracy: 0.9450 - val_loss: 0.2293 - learning_rate: 1.0000e-05
# Epoch 4/25
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 19s 387ms/step - accuracy: 0.9742 - loss: 0.1919 - val_accuracy: 0.9575 - val_loss: 0.2308 - learning_rate: 1.0000e-05
# Epoch 5/25
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 19s 379ms/step - accuracy: 0.9796 - loss: 0.1784 - val_accuracy: 0.8925 - val_loss: 0.3429 - learning_rate: 1.0000e-05
# Epoch 6/25
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 19s 378ms/step - accuracy: 0.9837 - loss: 0.1807 - val_accuracy: 0.9200 - val_loss: 0.2984 - learning_rate: 1.0000e-05
# Epoch 7/25
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 19s 379ms/step - accuracy: 0.9798 - loss: 0.1843 - val_accuracy: 0.9575 - val_loss: 0.2352 - learning_rate: 5.0000e-06
# Epoch 8/25
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 19s 378ms/step - accuracy: 0.9824 - loss: 0.1839 - val_accuracy: 0.9550 - val_loss: 0.2398 - learning_rate: 5.0000e-06
# Epoch 9/25
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 19s 378ms/step - accuracy: 0.9835 - loss: 0.1744 - val_accuracy: 0.9550 - val_loss: 0.2476 - learning_rate: 5.0000e-06
# Epoch 10/25
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 19s 378ms/step - accuracy: 0.9844 - loss: 0.1778 - val_accuracy: 0.9525 - val_loss: 0.2425 - learning_rate: 2.5000e-06
# Epoch 11/25
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 19s 379ms/step - accuracy: 0.9839 - loss: 0.1780 - val_accuracy: 0.9475 - val_loss: 0.2264 - learning_rate: 2.5000e-06
# Epoch 12/25
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 19s 386ms/step - accuracy: 0.9834 - loss: 0.1819 - val_accuracy: 0.9600 - val_loss: 0.2285 - learning_rate: 2.5000e-06
# Epoch 13/25
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 19s 378ms/step - accuracy: 0.9840 - loss: 0.1771 - val_accuracy: 0.9550 - val_loss: 0.2308 - learning_rate: 2.5000e-06
# Epoch 14/25
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 19s 378ms/step - accuracy: 0.9868 - loss: 0.1723 - val_accuracy: 0.9475 - val_loss: 0.2634 - learning_rate: 2.5000e-06
# Epoch 15/25
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 19s 377ms/step - accuracy: 0.9786 - loss: 0.1736 - val_accuracy: 0.9550 - val_loss: 0.2492 - learning_rate: 1.2500e-06
# Epoch 16/25
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 19s 377ms/step - accuracy: 0.9847 - loss: 0.1724 - val_accuracy: 0.9575 - val_loss: 0.2376 - learning_rate: 1.2500e-06
# Epoch 17/25
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 19s 378ms/step - accuracy: 0.9852 - loss: 0.1710 - val_accuracy: 0.9575 - val_loss: 0.2308 - learning_rate: 1.2500e-06
# Epoch 18/25
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 19s 379ms/step - accuracy: 0.9832 - loss: 0.1720 - val_accuracy: 0.9600 - val_loss: 0.2251 - learning_rate: 1.0000e-06
# Epoch 19/25
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 19s 377ms/step - accuracy: 0.9913 - loss: 0.1682 - val_accuracy: 0.9575 - val_loss: 0.2313 - learning_rate: 1.0000e-06
# Epoch 20/25
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 19s 377ms/step - accuracy: 0.9831 - loss: 0.1788 - val_accuracy: 0.9575 - val_loss: 0.2530 - learning_rate: 1.0000e-06
# ✅ Fold 1 Accuracy: 96.00%
# 📊 Classification Report:
#                precision    recall  f1-score   support
#
#    Monkeypox     0.9946    0.9250    0.9585       200
#       Others     0.9299    0.9950    0.9614       200
#
#     accuracy                         0.9600       400
#    macro avg     0.9623    0.9600    0.9600       400
# weighted avg     0.9623    0.9600    0.9600       400
#
# ✅ Fold 1 Cohen's Kappa: 0.9200
# 🔹 Sensitivity (Recall) for Monkeypox: 0.9250
# 🔹 Sensitivity (Recall) for Others: 0.9950
#
# ================ BOOTSTRAP 95% CI (Fold 1) ================
# Accuracy: 0.9600 (95% CI: 0.9399 – 0.9800)
# Precision (macro): 0.9623 (95% CI: 0.9427 – 0.9797)
# Recall (macro): 0.9600 (95% CI: 0.9388 – 0.9786)
# F1 (macro): 0.9599 (95% CI: 0.9390 – 0.9796)
# Cohen's Kappa: 0.9198 (95% CI: 0.8785 – 0.9592)
# AUC (ovr-macro): 0.9921 (95% CI: 0.9858 – 0.9969)
#
#
# ====================== FOLD 2/5 ======================
# Val class counts: {'Monkeypox': 200, 'Others': 200}
# Class weights: {0: 1.0, 1: 1.0}
# Epoch 1/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 56s 538ms/step - accuracy: 0.6819 - loss: 0.6534 - val_accuracy: 0.5150 - val_loss: 0.7901 - learning_rate: 1.0000e-04
# Epoch 2/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 17s 338ms/step - accuracy: 0.8654 - loss: 0.3877 - val_accuracy: 0.7325 - val_loss: 0.4981 - learning_rate: 1.0000e-04
# Epoch 3/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 17s 338ms/step - accuracy: 0.8884 - loss: 0.3365 - val_accuracy: 0.8725 - val_loss: 0.3881 - learning_rate: 1.0000e-04
# Epoch 4/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 17s 338ms/step - accuracy: 0.9197 - loss: 0.2852 - val_accuracy: 0.9100 - val_loss: 0.3369 - learning_rate: 1.0000e-04
# Epoch 5/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 17s 338ms/step - accuracy: 0.9251 - loss: 0.2745 - val_accuracy: 0.9275 - val_loss: 0.2971 - learning_rate: 1.0000e-04
# Epoch 6/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 16s 328ms/step - accuracy: 0.9436 - loss: 0.2530 - val_accuracy: 0.9200 - val_loss: 0.2771 - learning_rate: 1.0000e-04
# Epoch 7/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 17s 337ms/step - accuracy: 0.9342 - loss: 0.2542 - val_accuracy: 0.9325 - val_loss: 0.2553 - learning_rate: 1.0000e-04
# Epoch 8/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 16s 329ms/step - accuracy: 0.9464 - loss: 0.2406 - val_accuracy: 0.9325 - val_loss: 0.2461 - learning_rate: 1.0000e-04
# Epoch 9/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 17s 337ms/step - accuracy: 0.9618 - loss: 0.2207 - val_accuracy: 0.9400 - val_loss: 0.2411 - learning_rate: 1.0000e-04
# Epoch 10/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 17s 336ms/step - accuracy: 0.9700 - loss: 0.2110 - val_accuracy: 0.9600 - val_loss: 0.2255 - learning_rate: 1.0000e-04
# Epoch 1/25
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 64s 583ms/step - accuracy: 0.9616 - loss: 0.2124 - val_accuracy: 0.9050 - val_loss: 0.2858 - learning_rate: 1.0000e-05
# Epoch 2/25
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 19s 388ms/step - accuracy: 0.9626 - loss: 0.2032 - val_accuracy: 0.9450 - val_loss: 0.2473 - learning_rate: 1.0000e-05
# Epoch 3/25
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 19s 380ms/step - accuracy: 0.9713 - loss: 0.1953 - val_accuracy: 0.9175 - val_loss: 0.2706 - learning_rate: 1.0000e-05
# Epoch 4/25
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 19s 380ms/step - accuracy: 0.9687 - loss: 0.2058 - val_accuracy: 0.9225 - val_loss: 0.2546 - learning_rate: 1.0000e-05
# Epoch 5/25
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 19s 388ms/step - accuracy: 0.9773 - loss: 0.1890 - val_accuracy: 0.9500 - val_loss: 0.2402 - learning_rate: 1.0000e-05
# Epoch 6/25
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 19s 379ms/step - accuracy: 0.9711 - loss: 0.1892 - val_accuracy: 0.8825 - val_loss: 0.3287 - learning_rate: 1.0000e-05
# Epoch 7/25
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 19s 380ms/step - accuracy: 0.9887 - loss: 0.1722 - val_accuracy: 0.8325 - val_loss: 0.4315 - learning_rate: 1.0000e-05
# Epoch 8/25
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 19s 379ms/step - accuracy: 0.9830 - loss: 0.1795 - val_accuracy: 0.9425 - val_loss: 0.2347 - learning_rate: 1.0000e-05
# Epoch 9/25
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 19s 378ms/step - accuracy: 0.9782 - loss: 0.1839 - val_accuracy: 0.9175 - val_loss: 0.2616 - learning_rate: 1.0000e-05
# Epoch 10/25
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 19s 388ms/step - accuracy: 0.9821 - loss: 0.1721 - val_accuracy: 0.9550 - val_loss: 0.2178 - learning_rate: 1.0000e-05
# Epoch 11/25
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 19s 380ms/step - accuracy: 0.9767 - loss: 0.1856 - val_accuracy: 0.9550 - val_loss: 0.2281 - learning_rate: 1.0000e-05
# Epoch 12/25
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 19s 379ms/step - accuracy: 0.9825 - loss: 0.1722 - val_accuracy: 0.9450 - val_loss: 0.2272 - learning_rate: 1.0000e-05
# Epoch 13/25
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 19s 380ms/step - accuracy: 0.9934 - loss: 0.1666 - val_accuracy: 0.9400 - val_loss: 0.2384 - learning_rate: 1.0000e-05
# Epoch 14/25
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 19s 387ms/step - accuracy: 0.9885 - loss: 0.1677 - val_accuracy: 0.9625 - val_loss: 0.2079 - learning_rate: 5.0000e-06
# Epoch 15/25
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 19s 379ms/step - accuracy: 0.9831 - loss: 0.1789 - val_accuracy: 0.9625 - val_loss: 0.2034 - learning_rate: 5.0000e-06
# Epoch 16/25
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 19s 389ms/step - accuracy: 0.9828 - loss: 0.1768 - val_accuracy: 0.9675 - val_loss: 0.2001 - learning_rate: 5.0000e-06
# Epoch 17/25
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 19s 379ms/step - accuracy: 0.9884 - loss: 0.1694 - val_accuracy: 0.9425 - val_loss: 0.2313 - learning_rate: 5.0000e-06
# Epoch 18/25
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 19s 378ms/step - accuracy: 0.9794 - loss: 0.1781 - val_accuracy: 0.9375 - val_loss: 0.2260 - learning_rate: 5.0000e-06
# Epoch 19/25
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 19s 379ms/step - accuracy: 0.9853 - loss: 0.1661 - val_accuracy: 0.9650 - val_loss: 0.2042 - learning_rate: 5.0000e-06
# Epoch 20/25
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 19s 379ms/step - accuracy: 0.9876 - loss: 0.1758 - val_accuracy: 0.9475 - val_loss: 0.2114 - learning_rate: 2.5000e-06
# Epoch 21/25
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 19s 379ms/step - accuracy: 0.9869 - loss: 0.1683 - val_accuracy: 0.9525 - val_loss: 0.2068 - learning_rate: 2.5000e-06
# Epoch 22/25
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 19s 379ms/step - accuracy: 0.9878 - loss: 0.1665 - val_accuracy: 0.9675 - val_loss: 0.1986 - learning_rate: 2.5000e-06
# Epoch 23/25
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 19s 379ms/step - accuracy: 0.9950 - loss: 0.1593 - val_accuracy: 0.9550 - val_loss: 0.2046 - learning_rate: 2.5000e-06
# Epoch 24/25
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 19s 380ms/step - accuracy: 0.9889 - loss: 0.1595 - val_accuracy: 0.9450 - val_loss: 0.2150 - learning_rate: 2.5000e-06
# ✅ Fold 2 Accuracy: 96.75%
# 📊 Classification Report:
#                precision    recall  f1-score   support
#
#    Monkeypox     0.9845    0.9500    0.9669       200
#       Others     0.9517    0.9850    0.9681       200
#
#     accuracy                         0.9675       400
#    macro avg     0.9681    0.9675    0.9675       400
# weighted avg     0.9681    0.9675    0.9675       400
#
# ✅ Fold 2 Cohen's Kappa: 0.9350
# 🔹 Sensitivity (Recall) for Monkeypox: 0.9500
# 🔹 Sensitivity (Recall) for Others: 0.9850
#
# ================ BOOTSTRAP 95% CI (Fold 2) ================
# Accuracy: 0.9674 (95% CI: 0.9475 – 0.9825)
# Precision (macro): 0.9680 (95% CI: 0.9501 – 0.9830)
# Recall (macro): 0.9674 (95% CI: 0.9488 – 0.9826)
# F1 (macro): 0.9673 (95% CI: 0.9475 – 0.9825)
# Cohen's Kappa: 0.9347 (95% CI: 0.8951 – 0.9650)
# AUC (ovr-macro): 0.9949 (95% CI: 0.9901 – 0.9987)
#
#
# ====================== FOLD 3/5 ======================
# Val class counts: {'Monkeypox': 200, 'Others': 200}
# Class weights: {0: 1.0, 1: 1.0}
# Epoch 1/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 56s 536ms/step - accuracy: 0.6943 - loss: 0.6495 - val_accuracy: 0.6275 - val_loss: 0.5753 - learning_rate: 1.0000e-04
# Epoch 2/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 17s 337ms/step - accuracy: 0.8520 - loss: 0.3880 - val_accuracy: 0.8475 - val_loss: 0.4198 - learning_rate: 1.0000e-04
# Epoch 3/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 17s 339ms/step - accuracy: 0.9069 - loss: 0.3187 - val_accuracy: 0.9250 - val_loss: 0.3422 - learning_rate: 1.0000e-04
# Epoch 4/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 16s 328ms/step - accuracy: 0.9205 - loss: 0.2792 - val_accuracy: 0.9250 - val_loss: 0.3057 - learning_rate: 1.0000e-04
# Epoch 5/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 17s 336ms/step - accuracy: 0.9373 - loss: 0.2569 - val_accuracy: 0.9400 - val_loss: 0.2722 - learning_rate: 1.0000e-04
# Epoch 6/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 16s 329ms/step - accuracy: 0.9424 - loss: 0.2574 - val_accuracy: 0.9325 - val_loss: 0.2426 - learning_rate: 1.0000e-04
# Epoch 7/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 17s 338ms/step - accuracy: 0.9543 - loss: 0.2360 - val_accuracy: 0.9450 - val_loss: 0.2478 - learning_rate: 1.0000e-04
# Epoch 8/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 17s 338ms/step - accuracy: 0.9447 - loss: 0.2306 - val_accuracy: 0.9575 - val_loss: 0.2326 - learning_rate: 1.0000e-04
# Epoch 9/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 16s 327ms/step - accuracy: 0.9588 - loss: 0.2110 - val_accuracy: 0.9575 - val_loss: 0.2206 - learning_rate: 1.0000e-04
# Epoch 10/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 16s 329ms/step - accuracy: 0.9580 - loss: 0.2200 - val_accuracy: 0.9575 - val_loss: 0.2112 - learning_rate: 1.0000e-04
# Epoch 1/25
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 66s 583ms/step - accuracy: 0.9535 - loss: 0.2236 - val_accuracy: 0.9475 - val_loss: 0.2439 - learning_rate: 1.0000e-05
# Epoch 2/25
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 19s 387ms/step - accuracy: 0.9712 - loss: 0.2003 - val_accuracy: 0.9500 - val_loss: 0.2292 - learning_rate: 1.0000e-05
# Epoch 3/25
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 19s 387ms/step - accuracy: 0.9633 - loss: 0.2084 - val_accuracy: 0.9625 - val_loss: 0.2163 - learning_rate: 1.0000e-05
# Epoch 4/25
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 19s 379ms/step - accuracy: 0.9746 - loss: 0.1932 - val_accuracy: 0.9325 - val_loss: 0.2555 - learning_rate: 1.0000e-05
# Epoch 5/25
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 19s 380ms/step - accuracy: 0.9741 - loss: 0.1968 - val_accuracy: 0.9550 - val_loss: 0.2104 - learning_rate: 1.0000e-05
# Epoch 6/25
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 19s 379ms/step - accuracy: 0.9817 - loss: 0.1803 - val_accuracy: 0.9525 - val_loss: 0.2320 - learning_rate: 1.0000e-05
# Epoch 7/25
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 19s 379ms/step - accuracy: 0.9867 - loss: 0.1803 - val_accuracy: 0.9375 - val_loss: 0.2583 - learning_rate: 1.0000e-05
# Epoch 8/25
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 19s 379ms/step - accuracy: 0.9742 - loss: 0.1904 - val_accuracy: 0.9300 - val_loss: 0.2860 - learning_rate: 1.0000e-05
# Epoch 9/25
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 19s 379ms/step - accuracy: 0.9775 - loss: 0.1882 - val_accuracy: 0.9600 - val_loss: 0.2062 - learning_rate: 5.0000e-06
# Epoch 10/25
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 19s 379ms/step - accuracy: 0.9758 - loss: 0.1840 - val_accuracy: 0.9625 - val_loss: 0.2009 - learning_rate: 5.0000e-06
# Epoch 11/25
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 19s 378ms/step - accuracy: 0.9786 - loss: 0.1792 - val_accuracy: 0.9450 - val_loss: 0.2361 - learning_rate: 5.0000e-06
# ✅ Fold 3 Accuracy: 96.25%
# 📊 Classification Report:
#                precision    recall  f1-score   support
#
#    Monkeypox     0.9695    0.9550    0.9622       200
#       Others     0.9557    0.9700    0.9628       200
#
#     accuracy                         0.9625       400
#    macro avg     0.9626    0.9625    0.9625       400
# weighted avg     0.9626    0.9625    0.9625       400
#
# ✅ Fold 3 Cohen's Kappa: 0.9250
# 🔹 Sensitivity (Recall) for Monkeypox: 0.9550
# 🔹 Sensitivity (Recall) for Others: 0.9700
#
# ================ BOOTSTRAP 95% CI (Fold 3) ================
# Accuracy: 0.9628 (95% CI: 0.9450 – 0.9800)
# Precision (macro): 0.9629 (95% CI: 0.9445 – 0.9803)
# Recall (macro): 0.9628 (95% CI: 0.9439 – 0.9802)
# F1 (macro): 0.9627 (95% CI: 0.9446 – 0.9800)
# Cohen's Kappa: 0.9253 (95% CI: 0.8892 – 0.9600)
# AUC (ovr-macro): 0.9911 (95% CI: 0.9834 – 0.9970)
#
#
# ====================== FOLD 4/5 ======================
# Val class counts: {'Monkeypox': 200, 'Others': 200}
# Class weights: {0: 1.0, 1: 1.0}
# Epoch 1/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 56s 540ms/step - accuracy: 0.6891 - loss: 0.6380 - val_accuracy: 0.6525 - val_loss: 0.5672 - learning_rate: 1.0000e-04
# Epoch 2/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 17s 339ms/step - accuracy: 0.8396 - loss: 0.3955 - val_accuracy: 0.7925 - val_loss: 0.4677 - learning_rate: 1.0000e-04
# Epoch 3/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 17s 338ms/step - accuracy: 0.8850 - loss: 0.3502 - val_accuracy: 0.8775 - val_loss: 0.3850 - learning_rate: 1.0000e-04
# Epoch 4/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 17s 339ms/step - accuracy: 0.9169 - loss: 0.2915 - val_accuracy: 0.9100 - val_loss: 0.3242 - learning_rate: 1.0000e-04
# Epoch 5/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 17s 340ms/step - accuracy: 0.9330 - loss: 0.2666 - val_accuracy: 0.9275 - val_loss: 0.2960 - learning_rate: 1.0000e-04
# Epoch 6/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 16s 330ms/step - accuracy: 0.9329 - loss: 0.2591 - val_accuracy: 0.9275 - val_loss: 0.2789 - learning_rate: 1.0000e-04
# Epoch 7/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 16s 330ms/step - accuracy: 0.9421 - loss: 0.2426 - val_accuracy: 0.9250 - val_loss: 0.2668 - learning_rate: 1.0000e-04
# Epoch 8/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 17s 338ms/step - accuracy: 0.9489 - loss: 0.2329 - val_accuracy: 0.9350 - val_loss: 0.2485 - learning_rate: 1.0000e-04
# Epoch 9/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 16s 329ms/step - accuracy: 0.9603 - loss: 0.2247 - val_accuracy: 0.9325 - val_loss: 0.2703 - learning_rate: 1.0000e-04
# Epoch 10/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 17s 337ms/step - accuracy: 0.9617 - loss: 0.2133 - val_accuracy: 0.9375 - val_loss: 0.2379 - learning_rate: 1.0000e-04
# Epoch 1/25
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 66s 646ms/step - accuracy: 0.9622 - loss: 0.2171 - val_accuracy: 0.8800 - val_loss: 0.3806 - learning_rate: 1.0000e-05
# Epoch 2/25
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 19s 387ms/step - accuracy: 0.9698 - loss: 0.1970 - val_accuracy: 0.9450 - val_loss: 0.2456 - learning_rate: 1.0000e-05
# Epoch 3/25
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 19s 390ms/step - accuracy: 0.9725 - loss: 0.2015 - val_accuracy: 0.9475 - val_loss: 0.2369 - learning_rate: 1.0000e-05
# Epoch 4/25
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 19s 380ms/step - accuracy: 0.9723 - loss: 0.1938 - val_accuracy: 0.8625 - val_loss: 0.4369 - learning_rate: 1.0000e-05
# Epoch 5/25
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 19s 380ms/step - accuracy: 0.9840 - loss: 0.1820 - val_accuracy: 0.8825 - val_loss: 0.3901 - learning_rate: 1.0000e-05
# Epoch 6/25
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 19s 379ms/step - accuracy: 0.9849 - loss: 0.1823 - val_accuracy: 0.9425 - val_loss: 0.2666 - learning_rate: 1.0000e-05
# Epoch 7/25
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 19s 379ms/step - accuracy: 0.9766 - loss: 0.1879 - val_accuracy: 0.9425 - val_loss: 0.2539 - learning_rate: 5.0000e-06
# Epoch 8/25
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 19s 390ms/step - accuracy: 0.9822 - loss: 0.1761 - val_accuracy: 0.9500 - val_loss: 0.2515 - learning_rate: 5.0000e-06
# Epoch 9/25
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 19s 388ms/step - accuracy: 0.9874 - loss: 0.1740 - val_accuracy: 0.9600 - val_loss: 0.2269 - learning_rate: 5.0000e-06
# Epoch 10/25
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 19s 379ms/step - accuracy: 0.9750 - loss: 0.1900 - val_accuracy: 0.9400 - val_loss: 0.2302 - learning_rate: 5.0000e-06
# Epoch 11/25
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 19s 379ms/step - accuracy: 0.9816 - loss: 0.1843 - val_accuracy: 0.9000 - val_loss: 0.3169 - learning_rate: 5.0000e-06
# Epoch 12/25
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 19s 380ms/step - accuracy: 0.9804 - loss: 0.1770 - val_accuracy: 0.9250 - val_loss: 0.2650 - learning_rate: 5.0000e-06
# Epoch 13/25
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 19s 379ms/step - accuracy: 0.9808 - loss: 0.1724 - val_accuracy: 0.9550 - val_loss: 0.2189 - learning_rate: 2.5000e-06
# Epoch 14/25
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 19s 379ms/step - accuracy: 0.9879 - loss: 0.1768 - val_accuracy: 0.9575 - val_loss: 0.2223 - learning_rate: 2.5000e-06
# Epoch 15/25
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 19s 379ms/step - accuracy: 0.9829 - loss: 0.1711 - val_accuracy: 0.9450 - val_loss: 0.2412 - learning_rate: 2.5000e-06
# Epoch 16/25
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 19s 380ms/step - accuracy: 0.9870 - loss: 0.1657 - val_accuracy: 0.9450 - val_loss: 0.2388 - learning_rate: 2.5000e-06
# Epoch 17/25
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 19s 380ms/step - accuracy: 0.9813 - loss: 0.1780 - val_accuracy: 0.9600 - val_loss: 0.2262 - learning_rate: 1.2500e-06
# ✅ Fold 4 Accuracy: 96.00%
# 📊 Classification Report:
#                precision    recall  f1-score   support
#
#    Monkeypox     0.9894    0.9300    0.9588       200
#       Others     0.9340    0.9900    0.9612       200
#
#     accuracy                         0.9600       400
#    macro avg     0.9617    0.9600    0.9600       400
# weighted avg     0.9617    0.9600    0.9600       400
#
# ✅ Fold 4 Cohen's Kappa: 0.9200
# 🔹 Sensitivity (Recall) for Monkeypox: 0.9300
# 🔹 Sensitivity (Recall) for Others: 0.9900
#
# ================ BOOTSTRAP 95% CI (Fold 4) ================
# Accuracy: 0.9600 (95% CI: 0.9400 – 0.9775)
# Precision (macro): 0.9616 (95% CI: 0.9422 – 0.9798)
# Recall (macro): 0.9600 (95% CI: 0.9390 – 0.9782)
# F1 (macro): 0.9598 (95% CI: 0.9396 – 0.9775)
# Cohen's Kappa: 0.9197 (95% CI: 0.8794 – 0.9550)
# AUC (ovr-macro): 0.9896 (95% CI: 0.9821 – 0.9954)
#
#
# ====================== FOLD 5/5 ======================
# Val class counts: {'Monkeypox': 200, 'Others': 200}
# Class weights: {0: 1.0, 1: 1.0}
# Epoch 1/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 57s 541ms/step - accuracy: 0.6580 - loss: 0.7209 - val_accuracy: 0.7275 - val_loss: 0.5285 - learning_rate: 1.0000e-04
# Epoch 2/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 17s 337ms/step - accuracy: 0.8626 - loss: 0.3833 - val_accuracy: 0.8500 - val_loss: 0.4357 - learning_rate: 1.0000e-04
# Epoch 3/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 17s 337ms/step - accuracy: 0.8992 - loss: 0.3117 - val_accuracy: 0.9075 - val_loss: 0.3516 - learning_rate: 1.0000e-04
# Epoch 4/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 17s 337ms/step - accuracy: 0.9115 - loss: 0.2836 - val_accuracy: 0.9300 - val_loss: 0.3082 - learning_rate: 1.0000e-04
# Epoch 5/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 16s 328ms/step - accuracy: 0.9377 - loss: 0.2589 - val_accuracy: 0.9300 - val_loss: 0.2764 - learning_rate: 1.0000e-04
# Epoch 6/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 17s 338ms/step - accuracy: 0.9421 - loss: 0.2430 - val_accuracy: 0.9375 - val_loss: 0.2529 - learning_rate: 1.0000e-04
# Epoch 7/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 17s 338ms/step - accuracy: 0.9509 - loss: 0.2371 - val_accuracy: 0.9475 - val_loss: 0.2506 - learning_rate: 1.0000e-04
# Epoch 8/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 17s 338ms/step - accuracy: 0.9435 - loss: 0.2428 - val_accuracy: 0.9550 - val_loss: 0.2366 - learning_rate: 1.0000e-04
# Epoch 9/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 16s 327ms/step - accuracy: 0.9574 - loss: 0.2190 - val_accuracy: 0.9550 - val_loss: 0.2315 - learning_rate: 1.0000e-04
# Epoch 10/10
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 16s 328ms/step - accuracy: 0.9621 - loss: 0.2152 - val_accuracy: 0.9550 - val_loss: 0.2250 - learning_rate: 1.0000e-04
# Epoch 1/25
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 63s 582ms/step - accuracy: 0.9645 - loss: 0.2113 - val_accuracy: 0.9450 - val_loss: 0.2505 - learning_rate: 1.0000e-05
# Epoch 2/25
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 19s 379ms/step - accuracy: 0.9622 - loss: 0.2101 - val_accuracy: 0.9350 - val_loss: 0.2402 - learning_rate: 1.0000e-05
# Epoch 3/25
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 19s 379ms/step - accuracy: 0.9728 - loss: 0.1941 - val_accuracy: 0.9400 - val_loss: 0.2364 - learning_rate: 1.0000e-05
# Epoch 4/25
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 19s 380ms/step - accuracy: 0.9632 - loss: 0.2033 - val_accuracy: 0.9400 - val_loss: 0.2495 - learning_rate: 1.0000e-05
# Epoch 5/25
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 19s 387ms/step - accuracy: 0.9634 - loss: 0.2062 - val_accuracy: 0.9500 - val_loss: 0.2329 - learning_rate: 1.0000e-05
# Epoch 6/25
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 19s 388ms/step - accuracy: 0.9832 - loss: 0.1857 - val_accuracy: 0.9575 - val_loss: 0.2252 - learning_rate: 1.0000e-05
# Epoch 7/25
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 19s 378ms/step - accuracy: 0.9743 - loss: 0.1888 - val_accuracy: 0.9375 - val_loss: 0.2471 - learning_rate: 1.0000e-05
# Epoch 8/25
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 19s 379ms/step - accuracy: 0.9792 - loss: 0.1829 - val_accuracy: 0.9325 - val_loss: 0.2531 - learning_rate: 1.0000e-05
# Epoch 9/25
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 19s 389ms/step - accuracy: 0.9838 - loss: 0.1784 - val_accuracy: 0.9625 - val_loss: 0.2194 - learning_rate: 1.0000e-05
# Epoch 10/25
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 19s 378ms/step - accuracy: 0.9817 - loss: 0.1750 - val_accuracy: 0.9450 - val_loss: 0.2476 - learning_rate: 1.0000e-05
# Epoch 11/25
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 19s 379ms/step - accuracy: 0.9816 - loss: 0.1851 - val_accuracy: 0.9425 - val_loss: 0.2346 - learning_rate: 1.0000e-05
# Epoch 12/25
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 19s 379ms/step - accuracy: 0.9818 - loss: 0.1781 - val_accuracy: 0.9550 - val_loss: 0.2237 - learning_rate: 1.0000e-05
# Epoch 13/25
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 19s 378ms/step - accuracy: 0.9882 - loss: 0.1726 - val_accuracy: 0.9575 - val_loss: 0.2251 - learning_rate: 5.0000e-06
# Epoch 14/25
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 19s 380ms/step - accuracy: 0.9851 - loss: 0.1718 - val_accuracy: 0.9625 - val_loss: 0.2258 - learning_rate: 5.0000e-06
# Epoch 15/25
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 19s 379ms/step - accuracy: 0.9858 - loss: 0.1740 - val_accuracy: 0.9625 - val_loss: 0.2338 - learning_rate: 5.0000e-06
# Epoch 16/25
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 19s 378ms/step - accuracy: 0.9838 - loss: 0.1757 - val_accuracy: 0.9625 - val_loss: 0.2227 - learning_rate: 2.5000e-06
# Epoch 17/25
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 19s 380ms/step - accuracy: 0.9942 - loss: 0.1634 - val_accuracy: 0.9625 - val_loss: 0.2194 - learning_rate: 2.5000e-06
# ✅ Fold 5 Accuracy: 96.25%
# 📊 Classification Report:
#                precision    recall  f1-score   support
#
#    Monkeypox     0.9512    0.9750    0.9630       200
#       Others     0.9744    0.9500    0.9620       200
#
#     accuracy                         0.9625       400
#    macro avg     0.9628    0.9625    0.9625       400
# weighted avg     0.9628    0.9625    0.9625       400
#
# ✅ Fold 5 Cohen's Kappa: 0.9250
# 🔹 Sensitivity (Recall) for Monkeypox: 0.9750
# 🔹 Sensitivity (Recall) for Others: 0.9500
#
# ================ BOOTSTRAP 95% CI (Fold 5) ================
# Accuracy: 0.9624 (95% CI: 0.9425 – 0.9800)
# Precision (macro): 0.9627 (95% CI: 0.9430 – 0.9803)
# Recall (macro): 0.9625 (95% CI: 0.9432 – 0.9801)
# F1 (macro): 0.9623 (95% CI: 0.9425 – 0.9800)
# Cohen's Kappa: 0.9247 (95% CI: 0.8850 – 0.9600)
# AUC (ovr-macro): 0.9901 (95% CI: 0.9819 – 0.9964)
#
#
# ==================== 5-FOLD CV SUMMARY ====================
# acc         : 0.9625 ± 0.0027
# prec_macro  : 0.9635 ± 0.0023
# rec_macro   : 0.9625 ± 0.0027
# f1_macro    : 0.9625 ± 0.0028
# kappa       : 0.9250 ± 0.0055
# auc_macro   : 0.9916 ± 0.0019
#
# Per-fold table:
#    fold     acc  prec_macro  rec_macro  f1_macro  kappa  auc_macro
# 0     1  0.9600    0.962265     0.9600  0.959951  0.920   0.992150
# 1     2  0.9675    0.968073     0.9675  0.967490  0.935   0.994975
# 2     3  0.9625    0.962604     0.9625  0.962498  0.925   0.991050
# 3     4  0.9600    0.961662     0.9600  0.959964  0.920   0.989625
# 4     5  0.9625    0.962789     0.9625  0.962494  0.925   0.990025
#
# ✅ NOTE:
# If you want higher accuracy, try: UNFREEZE_LAST_N=60 and EPOCHS_FINETUNE=50
# If Kaggle memory is low, keep USE_EFFICIENTNET=False (default) and/or USE_XCEPTION=False.
